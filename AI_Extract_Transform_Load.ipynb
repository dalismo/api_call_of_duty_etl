# %%
import json
import requests 
from pprint import pprint
import time
import pandas as pd
from sqlalchemy import create_engine 
from config import api_key, username, password

# %% [markdown]
# # 1.0 Extract

# %% [markdown]
# # 1.1 Extract via API call from RAWG Database

# %% [markdown]
# ## 1.2 Perform API call on RAWG database

# %%
# Specify the URL
url = "https://api.rawg.io/api/games?key=" + api_key + "&dates=2012-01-01,2016-12-31"

# Lists for 'released', 'rating', 'metacritic', 'esrb_rating.name'
names = []
ratings = []
released = []
metacritic =[]
esrb = []
game_id = []

while url != None:
    
    try:
        # Make request and store response
        response = requests.get(url).json()

        # Identify URL as the "next" url (i.e. the next page) in the response
        url = response['next']
    
        # Store attributes into lists
        for game in response['results']:
            names.append(game['name'])
            ratings.append(game['rating'])
            released.append(game['released'])
            metacritic.append(game['metacritic'])
            game_id.append(game['id'])      
        
            try:   
                esrb.append(game['esrb_rating']["name"])
   
            except: 
                esrb.append("None") 
            
        # If there the "next" page is not available, then break the loop        
        if url == 'null':
            break
    
    # Once 10000 rows are reached, the "next" page becomes invalid. Ignore keyerror.
    except KeyError:
        break 
    
    time.sleep(1)

# %% [markdown]
# ## 1.3 Create dictionary from json results/lists

# %%
vg_dict = {'Game_ID':game_id, 'Name':names, 'Released':released, 'Ratings':ratings, 'Metacritic':metacritic, 'ESRB_rating':esrb}

# %% [markdown]
# ## 1.4 Create dataframe from dictionary

# %%
new_vg_data_df = pd.DataFrame(vg_dict)
new_vg_data_df
# Out:
#       Game_ID                              Name    Released  Ratings  \
# 0        3498                Grand Theft Auto V  2013-09-17     4.48
# 1        3328          The Witcher 3: Wild Hunt  2015-05-18     4.67
# 2        5286                Tomb Raider (2013)  2013-03-05     4.07
# 3         802                     Borderlands 2  2012-09-18     4.05
# 4        4291  Counter-Strike: Global Offensive  2012-08-21     3.59
# ...       ...                               ...         ...      ...
# 9995    15015                          Quell 4D  2016-10-14     0.00
# 9996    21527                   Ski Park Tycoon  2015-02-03     0.00
# 9997    21434                            Exodus  2014-07-11     0.00
# 9998    21057                     Jane's Realty  2015-10-21     0.00
# 9999    15513                Equin: The Lantern  2016-10-27     0.00
#
#       Metacritic ESRB_rating
# 0           97.0      Mature
# 1           92.0      Mature
# 2           86.0      Mature
# 3           89.0      Mature
# 4           81.0      Mature
# ...          ...         ...
# 9995         NaN        None
# 9996         NaN        None
# 9997         NaN        None
# 9998         NaN        None
# 9999         NaN        None
#
# [10000 rows x 6 columns]

# %% [markdown]
# # 1.5 Import Video Games Sales CSV file

# %%
csv_file = "Resources/Video_Games_Sales_as_at_22_Dec_2016.csv"

# %%
videogame_sales_df = pd.read_csv(csv_file)
videogame_sales_df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1           NaN         NaN         NaN       NaN    NaN
# 2          73.0         8.3       709.0  Nintendo      E
# 3          73.0         8.0       192.0  Nintendo      E
# 4           NaN         NaN         NaN       NaN    NaN

# %% [markdown]
# # 2.0 Transform

# %% [markdown]
# ## 2.1 EDA

# %% [markdown]
# ## 2.1.1 Sort the RAWG Videogame and Videogame Sales dataframes to check the years and games included

# %%
videogame_sales_df.sort_values("Year_of_Release", ascending = True, inplace = True)
videogame_sales_df
# Out:
#                                     Name Platform  Year_of_Release  \
# 262                            Asteroids     2600           1980.0
# 5360                             Freeway     2600           1980.0
# 546                      Missile Command     2600           1980.0
# 2650                              Boxing     2600           1980.0
# 4019                          Ice Hockey     2600           1980.0
# ...                                  ...      ...              ...
# 16376  PDC World Championship Darts 2008      PSP              NaN
# 16409                      Freaky Flyers       GC              NaN
# 16452                          Inversion       PC              NaN
# 16462        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16526                       Virtua Quest       GC              NaN
#
#               Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 262         Shooter               Atari      4.00      0.26       0.0
# 5360         Action          Activision      0.32      0.02       0.0
# 546         Shooter               Atari      2.56      0.17       0.0
# 2650       Fighting          Activision      0.72      0.04       0.0
# 4019         Sports          Activision      0.46      0.03       0.0
# ...             ...                 ...       ...       ...       ...
# 16376        Sports  Oxygen Interactive      0.01      0.00       0.0
# 16409        Racing             Unknown      0.01      0.00       0.0
# 16452       Shooter  Namco Bandai Games      0.01      0.00       0.0
# 16462     Adventure             Unknown      0.01      0.00       0.0
# 16526  Role-Playing             Unknown      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# 262           0.05          4.31           NaN           NaN         NaN
# 5360          0.00          0.34           NaN           NaN         NaN
# 546           0.03          2.76           NaN           NaN         NaN
# 2650          0.01          0.77           NaN           NaN         NaN
# 4019          0.01          0.49           NaN           NaN         NaN
# ...            ...           ...           ...           ...         ...
# 16376         0.00          0.01          43.0           7.0         NaN
# 16409         0.00          0.01          69.0          14.0         6.5
# 16452         0.00          0.01          59.0           6.0         6.7
# 16462         0.00          0.01           NaN           NaN         NaN
# 16526         0.00          0.01          55.0          19.0         5.5
#
#        User_Count                     Developer Rating
# 262           NaN                           NaN    NaN
# 5360          NaN                           NaN    NaN
# 546           NaN                           NaN    NaN
# 2650          NaN                           NaN    NaN
# 4019          NaN                           NaN    NaN
# ...           ...                           ...    ...
# 16376         NaN            Oxygen Interactive   E10+
# 16409         6.0                        Midway      T
# 16452       107.0             Saber Interactive      M
# 16462         NaN                           NaN    NaN
# 16526        12.0  Artificial Mind and Movement      T
#
# [16719 rows x 16 columns]

# %%
new_vg_data_df.sort_values("Released", ascending = True, inplace = True)
new_vg_data_df
# Out:
#       Game_ID                    Name    Released  Ratings  Metacritic  \
# 3814    41142    War of the Immortals  2012-01-01     0.00         NaN
# 3324    16757               1000 Amps  2012-01-01     3.67         NaN
# 4957    59026               The Light  2012-01-01     3.92         NaN
# 4856     4503               NFL Blitz  2012-01-03     3.80         NaN
# 2836    28363        UFC Undisputed 3  2012-01-03     3.65         NaN
# ...       ...                     ...         ...      ...         ...
# 3616    14567                 POLYWAR  2016-12-30     2.00         NaN
# 9549    12155           Space Journey  2016-12-30     0.00         NaN
# 6294    15160            Spooky Night  2016-12-31     0.00         NaN
# 2588       37  Star Trek: Bridge Crew  2016-12-31     3.52        75.0
# 7813      429                  Divide  2016-12-31     0.00         NaN
#
#        ESRB_rating
# 3814          None
# 3324          None
# 4957          None
# 4856  Everyone 10+
# 2836          Teen
# ...            ...
# 3616          None
# 9549          None
# 6294          None
# 2588          None
# 7813          Teen
#
# [10000 rows x 6 columns]

# %% [markdown]
# ## 2.2 Data Cleaning

# %% [markdown]
# ## 2.2.1 Retain only columns needed from the Video Games Sales dataframe

# %%
videogame_sales_df = videogame_sales_df[['Name','Platform','Genre','Global_Sales']]
videogame_sales_df
# Out:
#                                 Name Platform         Genre  Global_Sales
# 0                         Wii Sports      Wii        Sports         82.53
# 1                  Super Mario Bros.      NES      Platform         40.24
# 2                     Mario Kart Wii      Wii        Racing         35.52
# 3                  Wii Sports Resort      Wii        Sports         32.77
# 4           Pokemon Red/Pokemon Blue       GB  Role-Playing         31.37
# ...                              ...      ...           ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3        Action          0.01
# 16715               LMA Manager 2007     X360        Sports          0.01
# 16716        Haitaka no Psychedelica      PSV     Adventure          0.01
# 16717               Spirits & Spells      GBA      Platform          0.01
# 16718            Winning Post 8 2016      PSV    Simulation          0.01
#
# [16719 rows x 4 columns]

# %% [markdown]
# ## 2.2.2 Rename columns in the videogames sales dataframe to clearer column names

# %%
videogame_sales_df = videogame_sales_df.rename(columns = {'Global_Sales':'Sales_Units_in_millions', 'Name':'Game_Name'})
videogame_sales_df
# Out:
#                            Game_Name Platform         Genre  \
# 0                         Wii Sports      Wii        Sports
# 1                  Super Mario Bros.      NES      Platform
# 2                     Mario Kart Wii      Wii        Racing
# 3                  Wii Sports Resort      Wii        Sports
# 4           Pokemon Red/Pokemon Blue       GB  Role-Playing
# ...                              ...      ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3        Action
# 16715               LMA Manager 2007     X360        Sports
# 16716        Haitaka no Psychedelica      PSV     Adventure
# 16717               Spirits & Spells      GBA      Platform
# 16718            Winning Post 8 2016      PSV    Simulation
#
#        Sales_Units_in_millions
# 0                        82.53
# 1                        40.24
# 2                        35.52
# 3                        32.77
# 4                        31.37
# ...                        ...
# 16714                     0.01
# 16715                     0.01
# 16716                     0.01
# 16717                     0.01
# 16718                     0.01
#
# [16719 rows x 4 columns]

# %% [markdown]
# ## 2.2.3 Replace the NaN values in Metracritic to Not Rated

# %%
new_vg_data_df['Metacritic'].fillna('Not Rated', inplace = True)
new_vg_data_df
# Out:
#       Game_ID                    Name    Released  Ratings Metacritic  \
# 3814    41142    War of the Immortals  2012-01-01     0.00  Not Rated
# 3324    16757               1000 Amps  2012-01-01     3.67  Not Rated
# 4957    59026               The Light  2012-01-01     3.92  Not Rated
# 4856     4503               NFL Blitz  2012-01-03     3.80  Not Rated
# 2836    28363        UFC Undisputed 3  2012-01-03     3.65  Not Rated
# ...       ...                     ...         ...      ...        ...
# 3616    14567                 POLYWAR  2016-12-30     2.00  Not Rated
# 9549    12155           Space Journey  2016-12-30     0.00  Not Rated
# 6294    15160            Spooky Night  2016-12-31     0.00  Not Rated
# 2588       37  Star Trek: Bridge Crew  2016-12-31     3.52         75
# 7813      429                  Divide  2016-12-31     0.00  Not Rated
#
#        ESRB_rating
# 3814          None
# 3324          None
# 4957          None
# 4856  Everyone 10+
# 2836          Teen
# ...            ...
# 3616          None
# 9549          None
# 6294          None
# 2588          None
# 7813          Teen
#
# [10000 rows x 6 columns]

# %% [markdown]
# ## 2.2.4 Rename columns in the metacritic dataframe to clearer column names

# %%
new_vg_data_df = new_vg_data_df.rename(columns = {'Name':'Game_Name', 'Released':'Release_Date'})
new_vg_data_df
# Out:
#       Game_ID               Game_Name Release_Date  Ratings Metacritic  \
# 3814    41142    War of the Immortals   2012-01-01     0.00  Not Rated
# 3324    16757               1000 Amps   2012-01-01     3.67  Not Rated
# 4957    59026               The Light   2012-01-01     3.92  Not Rated
# 4856     4503               NFL Blitz   2012-01-03     3.80  Not Rated
# 2836    28363        UFC Undisputed 3   2012-01-03     3.65  Not Rated
# ...       ...                     ...          ...      ...        ...
# 3616    14567                 POLYWAR   2016-12-30     2.00  Not Rated
# 9549    12155           Space Journey   2016-12-30     0.00  Not Rated
# 6294    15160            Spooky Night   2016-12-31     0.00  Not Rated
# 2588       37  Star Trek: Bridge Crew   2016-12-31     3.52         75
# 7813      429                  Divide   2016-12-31     0.00  Not Rated
#
#        ESRB_rating
# 3814          None
# 3324          None
# 4957          None
# 4856  Everyone 10+
# 2836          Teen
# ...            ...
# 3616          None
# 9549          None
# 6294          None
# 2588          None
# 7813          Teen
#
# [10000 rows x 6 columns]

# %% [markdown]
# ## 2.2.5 Save cleaned dataframes as csv files

# %%
new_vg_data_df.to_json('Resources/rawg_vg_data.json')

# %%
new_vg_data_df.to_csv('Resources/rawg_vg_data.csv', index=False)

# %% [markdown]
# ## 2.2.6 Merge the two dataframes

# %%
merged_df = new_vg_data_df.merge(videogame_sales_df, how='inner', on='Game_Name')

# %% [markdown]
# ## 2.2.7 Locate the Game with the same Platform being shown twice

# %%
merged_df.loc[merged_df['Game_ID'] ==4273]
# Out:
#      Game_ID      Game_Name Release_Date  Ratings Metacritic   ESRB_rating  \
# 127     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 128     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 129     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 130     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 131     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 132     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
#
#     Platform   Genre  Sales_Units_in_millions
# 127     X360  Sports                     2.86
# 128      PS3  Sports                     2.56
# 129      Wii  Sports                     0.50
# 130      PSV  Sports                     0.30
# 131     WiiU  Sports                     0.23
# 132      PS3  Sports                     0.01

# %% [markdown]
# ## 2.2.8 Combine the sales unit for Game ID 4273 Platform PS3 by summing the two rows

# %%
merged_df.at[128, 'Sales_Units_in_millions'] = 2.57

# %%
merged_df.loc[merged_df['Game_ID'] ==4273]
# Out:
#      Game_ID      Game_Name Release_Date  Ratings Metacritic   ESRB_rating  \
# 127     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 128     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 129     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 130     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 131     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 132     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
#
#     Platform   Genre  Sales_Units_in_millions
# 127     X360  Sports                     2.86
# 128      PS3  Sports                     2.57
# 129      Wii  Sports                     0.50
# 130      PSV  Sports                     0.30
# 131     WiiU  Sports                     0.23
# 132      PS3  Sports                     0.01

# %% [markdown]
# ## 2.2.9 Drop the extra row

# %%
merged_df.drop(index=132, inplace = True)

# %%
merged_df.loc[merged_df['Game_ID'] ==4273]
# Out:
#      Game_ID      Game_Name Release_Date  Ratings Metacritic   ESRB_rating  \
# 127     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 128     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 129     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 130     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
# 131     4273  Madden NFL 13   2012-08-28     2.68  Not Rated  Everyone 10+
#
#     Platform   Genre  Sales_Units_in_millions
# 127     X360  Sports                     2.86
# 128      PS3  Sports                     2.57
# 129      Wii  Sports                     0.50
# 130      PSV  Sports                     0.30
# 131     WiiU  Sports                     0.23

# %% [markdown]
# ## 2.2.10 Check each Game name has a Game ID

# %%
print(len(merged_df['Game_ID']))
print(len(merged_df['Game_Name']))
# Out:
# 1231
# 1231

# %% [markdown]
# ## 2.3 Get data into separate dataframes to match tables

# %%
platform_df = merged_df[['Platform']]
platform_df = platform_df.drop_duplicates()
platform_df = platform_df.rename(columns = {'Platform':'platform_id'})
platform_df
# Out:
#     platform_id
# 0            PS
# 1           N64
# 2           PS3
# 3          X360
# 4            PC
# 5           3DS
# 12          PSV
# 27         WiiU
# 33           DS
# 35          PS2
# 48          Wii
# 81          PS4
# 83         XOne
# 109          GB
# 110         PSP
# 197          XB
# 198          GC
# 286         GBA
# 505         NES
# 555        SNES

# %%
esrb_df = merged_df[['Game_ID','ESRB_rating']]
esrb_df = esrb_df.drop_duplicates()
esrb_df
# Out:
#       Game_ID   ESRB_rating
# 0        4503  Everyone 10+
# 2       28363          Teen
# 4       12092          None
# 5       27142          None
# 6       18142          None
# ...       ...           ...
# 1223      864        Mature
# 1226     9539          None
# 1227      572          Teen
# 1228    10061        Mature
# 1230      729          Teen
#
# [566 rows x 2 columns]

# %%
ratings_df = merged_df[['Game_ID','Metacritic','Ratings']]
ratings_df = ratings_df.drop_duplicates()
ratings_df = ratings_df.rename(columns = {'Ratings':'Rating'})
ratings_df
# Out:
#       Game_ID Metacritic  Rating
# 0        4503  Not Rated    3.80
# 2       28363  Not Rated    3.65
# 4       12092         81    4.13
# 5       27142  Not Rated    4.00
# 6       18142         67    2.38
# ...       ...        ...     ...
# 1223      864         86    4.26
# 1226     9539         43    3.10
# 1227      572         69    0.00
# 1228    10061         79    3.86
# 1230      729  Not Rated    0.00
#
# [566 rows x 3 columns]

# %%
sales_df = merged_df[['Game_ID','Platform','Sales_Units_in_millions']]
sales_df = sales_df.rename(columns = {'Platform':'platform_id'})
# sales_df.loc[sales_df['Game_ID']==4273]
sales_df
# Out:
#       Game_ID platform_id  Sales_Units_in_millions
# 0        4503          PS                     1.50
# 1        4503         N64                     1.06
# 2       28363         PS3                     1.03
# 3       28363        X360                     0.99
# 4       12092          PC                     0.17
# ...       ...         ...                      ...
# 1226     9539          PC                     0.02
# 1227      572         PS4                     0.10
# 1228    10061         PS4                     1.13
# 1229    10061        XOne                     0.36
# 1230      729         Wii                     0.75
#
# [1230 rows x 3 columns]

# %%
game_df = merged_df[['Game_ID','Game_Name','Release_Date','Genre']]
game_df = game_df.drop_duplicates()
# game_df.loc[game_df['Game_ID']==4273]
game_df
# Out:
#       Game_ID                                Game_Name Release_Date  \
# 0        4503                                NFL Blitz   2012-01-03
# 2       28363                         UFC Undisputed 3   2012-01-03
# 4       12092  Age of Empires III: Complete Collection   2012-01-05
# 5       27142    Rhythm Thief & the Emperor's Treasure   2012-01-19
# 6       18142                                 Oil Rush   2012-01-25
# ...       ...                                      ...          ...
# 1223      864                             Dishonored 2   2016-11-10
# 1226     9539               RollerCoaster Tycoon World   2016-11-16
# 1227      572                            EVE: Valkyrie   2016-11-17
# 1228    10061                             Watch Dogs 2   2016-11-28
# 1230      729                                  We Sing   2016-12-01
#
#            Genre
# 0         Sports
# 2         Action
# 4       Strategy
# 5           Misc
# 6       Strategy
# ...          ...
# 1223      Action
# 1226  Simulation
# 1227     Shooter
# 1228      Action
# 1230        Misc
#
# [566 rows x 4 columns]

# %% [markdown]
# # 3.0 Load

# %% [markdown]
# ## 3.1 Connect to local database

# %%
rds_connection_string = f"{username}:{password}@localhost:5432/game_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ## 3.2 Check for tables

# %%
engine.table_names()
# Out:
# ['Game', 'Ratings', 'ESRB_Rating', 'Platform', 'Sales_Platform']

# %% [markdown]
# ## 3.3 Export data from dataframes to tables

# %%
game_df.to_sql("Game", con=engine, index=False, if_exists="append")

# %%
platform_df.to_sql("Platform", con=engine, index=False, if_exists="append")

# %%
sales_df.to_sql("Sales_Platform", con=engine, index=False, if_exists="append")

# %%
ratings_df.to_sql("Ratings", con=engine, index=False, if_exists="append")

# %%
esrb_df.to_sql("ESRB_Rating", con=engine, index=False, if_exists="append")

# %% [markdown]
# ## 3.4 Confirm data has been added by querying tables
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from Game', con=engine).head()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# ~\anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                     self.dialect.do_execute(
# -> 1277                         cursor, statement, parameters, context
#    1278                     )
#
# ~\anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# UndefinedTable: relation "game" does not exist
# LINE 1: select * from Game
#                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-261-9715db0f53ec> in <module>
# ----> 1 pd.read_sql_query('select * from Game', con=engine).head()
#
# ~\anaconda3\envs\pythondata\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\anaconda3\envs\pythondata\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# ~\anaconda3\envs\pythondata\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# ~\anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2235
#    2236         connection = self._contextual_connect(close_with_result=True)
# -> 2237         return connection.execute(statement, *multiparams, **params)
#    2238
#    2239     def scalar(self, statement, *multiparams, **params):
#
# ~\anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1001         """
#    1002         if isinstance(object_, util.string_types[0]):
# -> 1003             return self._execute_text(object_, multiparams, params)
#    1004         try:
#    1005             meth = object_._execute_on_connection
#
# ~\anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1176             parameters,
#    1177             statement,
# -> 1178             parameters,
#    1179         )
#    1180         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~\anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509             elif should_wrap:
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#    1513             else:
#
# ~\anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
#    1276                     self.dialect.do_execute(
# -> 1277                         cursor, statement, parameters, context
#    1278                     )
#    1279
#
# ~\anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedTable) relation "game" does not exist
# LINE 1: select * from Game
#                       ^
#
# [SQL: select * from Game]
# (Background on this error at: http://sqlalche.me/e/13/f405)
